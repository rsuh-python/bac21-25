# %% [markdown]
# Итоговый балл за семестр - процент решенных задач. Необходимо прокомментировать решения и ответить на вопросы устно во время сдачи зачета.

# %% [markdown]
# #### Задача 1.
#
# Напишите класс-счетчик: основная задача этого класса - считать количество вызовов функций, к которым он применяется (если умеете пользоваться синтаксисом декораторов - хорошо, но я за него спрошу). В этом классе явно нужно переопределить какой-то магический метод.

# %%
class CallCounter:
    # your code here
      
def anyfunc():
    print()
    
wrapped = CallCounter(anyfunc)
wrapped()

# %% [markdown]
# #### Задача 2 (за изобретательность можно получить + 1).
#
# Напишите программу, имитирующую деятельность лингвиста. У нас должен быть класс "Лингвист", у которого есть какие-то атрибуты (обычно имя, аффилиация, публикации, стаж работы) и есть методы: писать статью, поехать в экспедицию, посетить конференцию. Также нужен класс "Публикация" и класс "Область экспедиции". Лингвист не может написать статью, если у него недостаточно полевого материала - который он набирает в экспедициях. В зависимости от области экспедиции материала набирается много или мало. Конференции и статьи дают лингвисту опыт.
#
# В этой задаче приветствуется фантазия.

# %%
# your code here

# %% [markdown]
# #### Задача 3.
#
# Изучите библиотеку PyQt5 и напишите с ее использованием программу - графический интерфейс для библиотеки googletrans: интерфейс должен содержать строку для ввода и кнопку "перевести", а языки - выбираться в двух выпадающих списках.

# %%
# эту задачу лучше писать в .py

# %% [markdown]
# #### Задача 4.
#
# Сделайте выгрузку для любого достаточно большого поискового запроса по ГИКРЯ. С помощью pandas:
# - удалите тексты-дубликаты.
# - выведите статистику по выгрузке: сколько представлено городов, каков диапазон дат публикации текстов и дат рождения авторов, сколько уникальных авторов. Есть ли какие-нибудь странные значения в датах публикации или датах рождения?
# - отфильтруйте выгрузку таким образом, чтобы в табличке остались только вхождения из 5 самых частотных городов, и если были странные выбросы в датах публикации, такие вхождения тоже надо отбросить. Удалите все пропущенные значения и оставьте только три колонки:  city, authorid, year.
# - на основе получившегося создайте таблицу, где в качестве индексов будут годы публикации, в качестве колонок - 5 самых частотных городов, а в значениях этой таблицы будет количество уникальных авторов для этого года и города. NaN заполните нулями.
# - в библиотеке seaborn постройте график heatmap для получившейся таблицы. В ячейках heatmap должны отображаться цифры.

# %%
# your code here

# %% [markdown]
# #### Задача 5.
#
# Изучите библиотеку wikipedia-api, разберитесь, как скачивать статьи из указанной категории. Напишите скрипт, который будет скачивать тексты статей из выбранной категории, при этом обезопасьте себя от бана с помощью функции sleep из модуля time; а для того, чтобы при работе скрипта было видно, какая статья сейчас скачалась и сколько их всего, добавьте соответствующие виджеты ipywidgets.

# %%
# your code here

# %% [markdown]
# #### Задача 6.
#
# Напишите скрипт - конвертер картинок: скрипт должен работать из командной строки\терминала и принимать 1) путь к файлу 2) расширение, в которое нужно сконвертировать. Можно ограничиться расширениями .jpg, .png и .ico.

# %%
# эту задачу надо писать в .py

# %% [markdown]
# #### Задача 7.
#
# Постройте три любых дерева составляющих в LaTeX.

# %% [markdown]
# #### Задача 8.
#
# Напишите регулярное выражение для поиска пути файла в операционной системе UNIX или Windows (посмотрите: у них различающиеся стандарты). Регулярному выражению должно быть все равно, какая операционная система. Путь файла может быть абсолютным или относительным, может начинаться на букву диска. Регулярное выражение должно содержать две группы, в одной должно отлавливаться имя файла, а в другой его расширение. (Считаем, что у файла обязательно есть расширение).

# %%
# your regex here

# %% [markdown]
# #### Задача 9.
#
# Дано предложение:
#
# ```
# #[[Time: Обычно"обычно:#frequentative_adverbs_adj:FREQUENTATIVE"] [Experiencer_Metaphoric: бюджет"бюджет:бюджет:BUDGET"] [[ко"к:#preposition:PREPOSITION"] [OrderInTimeAndSpace: второму"второй:TWO_ORDINAL"] Object_Situation: чтению "чтение:READING_OF_THE_DRAFT_LAW"] Predicate: готовится"готовить:готовить:PREPAREDNESS" [[DegreeApproximative: непосредственно"непосредственный:DIRECT_OBLIQUE"] [в"в_Prepositional:#preposition:PREPOSITION"] Locative: Думе"дума:дума:DUMA"]#: [[Agent: депутаты"депутат:депутат:DEPUTY"] Specification_Clause: корректируют"корректировать:корректировать:TO_CORRECT" [[Agent: правительственные"правительство:правительство:GOVERNMENT"] Object_Situation: планы"план:план:SCHEDULE_FOR_ACTIVITY"]]].
# ```
#
# В этом предложении каждое слово размечено семантической ролью, лексическим классом и семантическим классом. Роль - то, что идет сразу после квадратной скобки до :, потом идет само слово, потом его лемма, а через двоеточие идут лекс. класс и сем. класс (заглавными буквами).
#
# Напишите регулярное выражение, которое будет находить 1) сем. роль 2) словоформу 3) лемму 4) лексический класс 5) семантический класс в пяти группах.

# %%
# your regex here

# %% [markdown]
# #### Задача 10.
#
# Для предложения выше с помощью рекурсии и регулярных выражений извлеките все группы составляющих. У вас должны получиться списки от самого большого с одним элементом, в котором содержится все предложение, до списка с элементами, в каждом из которых находится содержимое самых глубоких квадратных скобок.

# %%
# your code here
