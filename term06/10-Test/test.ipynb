# %% [markdown]
# #### Задача 1 (5 баллов).
#
# Напишем игру "ферма". Наш игрок - экземпляр класса "фермер", у которого есть имя, стартовая сумма денег и объект класса "ферма". У объекта класса "ферма" есть жилплощадь (для самого фермера), а также могут быть поле для картошки, например (с площадью), огород под огурцы, постройки для домашних животных (с вместимостью). Наш фермер может покупать семена и животных, собирать урожай и взаимодействовать с животными (коров можно доить, свиней можно зарезать и продать мясо). Игра консольная, поэтому придется выводить нужную информацию через запросы игрока (игрок может захотеть знать, сколько у него есть животных, какие у него есть огороды-поля и так далее).
#
# Необходимо написать не только нужные классы, но и сам процесс игры.

# %%
# your code here

# %% [markdown]
# #### Задача 2 (3 балла).
#
# Есть такой формат лингвистической разметки, очень похожий на Universal Dependencies - CoBaLD. Он тоже размечается в conllu, но в последних двух колонках у него размечаются семантические роли слов и семантические классы. Датасет в этом формате есть [тут](https://github.com/CobaldAnnotation/CobaldRus/tree/main/1.0) (файл train.conllu - осторожно, он большой!).
#
# Напишите такой скрипт, который будет автоматически собирать примеры на семантические классы (10 колонка): скрипт должен собрать словарик, где в ключах будут все семантические классы, которые есть в датасете, а в значениях - хотя бы по одному предложению со словом соответствующего класса.
#
# На дополнительный балл: добавьте возможность вывода примеров по запросу класса с использованием colorama или termcolor таким образом, чтобы слово с нужным сем. классом выделялось каким-нибудь цветом.

# %%
# your code here

# %% [markdown]
# #### Задача 3 (2 балла).
#
# Формат синтаксической разметки содержит в себе квадратные скобки, которые обозначают составляющие, например:
#
#     [[Красивая [девочка]] идет [по [улице]]].
#
# Нужно извлечь все содержимое скобок таким образом, чтобы получилось несколько списков с составляющими, в первом должно быть все предложение целиком, а в последнем - отдельные слова. Подсказка: можно использовать, например, цикл while и re.sub.

# %%
# your code here

# %% [markdown]
# #### Задача 4 (1 балл).
#
# Напишите функцию для просмотра палитр seaborn, оберните ее в interact, чтобы можно было в выпадающем списке выбирать название палитры.

# %%
# your code here

# %% [markdown]
# #### Задача 5 (4 балла).
#
# Откройте датасет "Covid Live", посмотрите первые пять его строчек. Переименуйте названия колонок таким образом, чтобы было:
#
#     Country,\nOther => Country_Other
#     Total\nCases => Total_Cases
#     Deaths/\n1M pop => Deaths_1M pop
#
# То есть, чтобы не было пробелов и было удобно выделять название колонки по двойному щелчку.
#
# (Для последней задачи понадобится написать простенькую регулярку).

# %%
# your code here

# %% [markdown]
# Выведите информацию по датасету. Попробуйте понять, что там за данные хранятся.

# %%
# your code here

# %% [markdown]
# Давайте наш датасет почистим: нам, скорее всего, понадобятся не все колонки, + хотелось бы избавиться от пропущенных значений NaN. Посмотрите, сколько в итоге останется строк в таблице. Не хотелось бы, чтобы их было три!

# %%
# your code here

# %% [markdown]
# Давайте сменим тип числовых данных на правильный (вместо строк). Заметьте, это не так просто: в наших данных что-то будет вам мешать.

# %%
# your code here

# %% [markdown]
# Посчитайте, сколько, по этим данным, всего умерло людей от ковида. А сколько выздоровело?

# %%
# your code here

# %% [markdown]
# Добавим новую колонку к нашей таблице: 'death_to_recovered', а в ней посчитаем соотношение смертей к выздоровевшим. Страна с наименьшим таким значением - удачливее всех :). Попробуем отсортировать табличку по этим значениям (используйте метод DataFrame.sort_values(column)).

# %%
# your code here

# %% [markdown]
# #### Задача 6 (1 балл).
#
# Постройте в латехе такое же дерево, как на картинке tree.png.

# %%
# your code here

# %% [markdown]
# #### Задача 7 (1 балл).
#
# Напишите скрипт, который будет превращать выгрузку по запросу в ГИКРЯ из xlsx в docx, но таким образом, чтобы в docx печатался порядковый номер вхождения, левый и правый контекст, а слово по запросу было выделено жирным. Остальные сведения из xlsx можно не печатать.

# %%
# your code here

# %% [markdown]
# #### Задача 8 (1 балл).
#
# Возьмите любую (свою любимую, например) книгу, только достаточно большую. С помощью регулярных выражений подсчитайте, сколько раз в ней упоминались разные герои, и нарисуйте график их популярности.

# %%
# your code here

# %% [markdown]
# #### Задача 9 (1 балл).
#
# Напишите самый простой сентенайзер: скрипт, который будет делить текст на предложения. Проанализируйте, какие могут быть сложные случаи (если ваш сентенайзер не сможет учесть все, это не страшно, важно, чтобы вы знали, какие его поломают).

# %%
# your code here

# %% [markdown]
# #### Задача 10 (1 балл).
#
# На самом деле для задачи деления текста на предложения для русского языка существует простенькая библиотека rusenttokenize. Разберитесь с ней и попробуйте проверить, какие сложные случаи могут поломать эту библиотеку.

# %%
# your code here

# %% [markdown]
# #### Задача 11 (необязательная - 5 баллов).
#
# Физтехам дали список тем для курсовых работ, и они оценили те темы, которые им нравятся, с помощью баллов в диапазоне от 0 до 1. Известно, что есть такой алгоритм - linear sum assignment, который применяют, когда нужно распределить какие-нибудь штуки таким образом, чтобы оптимально учесть пожелания: этот алгоритм идеально применяется к задаче "распредели темы курсовых между физтехами так, чтобы все остались довольны". Можно попробовать почитать на [википедии](https://ru.wikipedia.org/wiki/%D0%97%D0%B0%D0%B4%D0%B0%D1%87%D0%B0_%D0%BE_%D0%BD%D0%B0%D0%B7%D0%BD%D0%B0%D1%87%D0%B5%D0%BD%D0%B8%D1%8F%D1%85), но в принципе необязательно.
#
# Этот алгоритм есть в библиотеке scipy. Помогите физтехам с его помощью: нужно 1) считать информацию из эксельки с помощью pandas 2) заполнить пропуски нулями 3) применить к числовым данным алгоритм из scipy, он вернет два списочка: индексы рядов в таблице и индексы колонок 4) Вывести список имен студентов и список приписанных тем.
#
# Подсказки: 1) мы максимизируем, а не минимизируем баллы. Может понадобиться включить какой-то параметр у функции 2) scipy не скушает датафрейм и подавится: зато он отлично умеет работать с numpy-массивами, которые можно получить из датафрейма с помощью to_numpy() или df.values (второе - атрибут, не метод!)

# %%
# your code here
