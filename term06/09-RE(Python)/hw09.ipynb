# %% [markdown]
# #### Задача 1.
#
# Пишем программу - помощник обнаружения тавтологии: ищем в тексте повторяющиеся слова, которые находятся на расстоянии от 2 до 10 слов друг от друга. В простом случае считаем, что пунктуации у нас нет, в сложном можете попробовать ее тоже учесть.

# %%
# your code here

# %% [markdown]
# #### Задача 2.
#
# Найти в тексте все употребления слов "понравилось" и "впечатлило" такие, что непосредственно перед ними НЕ стоит "не". Время прошедшее, но род/число могут быть любыми.

# %%
# your code here

# %% [markdown]
# #### Задача 3.
#
# Увеличить все встретившиеся в тексте четные числа на 1, а нечетные на 2, в том числе и отрицательные. Перед числом может стоять знак. Считаем, что между знаком и числом пробела нет.

# %%
# your code here

# %% [markdown]
# #### Задача 4.
#
# 1. Текст состоит из строк (lines). Удалите одним регулярным выражением все пробелы в началах всех строк, и все пробелы в концах всех строк.
# 2. То же, но теперь не только обычные пробелы, а все пробельные символы (пробелы внутри строк должны остаться, разумеется). При этом, дополнительно нужно удалить все пустые строки (пустые вообще, а так же состоящие только из пробельных символов). Попробуйте сделать это за одну операцию re.sub.
# 3. Сделайте то же самое без регулярных выражений в одну строчку, используя built-in функцию filter. (можно погуглить, как она работает).

# %%
# your code here

# %% [markdown]
# #### Задача 5 (если в классах - 2 балла).
#
# Вспомним программу - телефонный справочник, которую мы писали в прошлом семестре. У пользователя есть выбор из двух действий (ну кроме выхода): ввести новую запись и найти из существующих. База данных должна записываться с помощью библиотеки pickle и считываться заново при запуске программы. Попробуйте написать эту программу в классах. Главное: программа должна при вводе проверять, что номер телефона действительно соответствует формату (формат определите сами, какой вам больше нравится - хх-хх-хх, х(ххх)хх-хх-хх...), а фамилия человека должна содержать только буквы и пробелы.

# %%
# your code here
